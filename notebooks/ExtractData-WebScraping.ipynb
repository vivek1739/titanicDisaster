# %%
import requests 
from bs4 import BeautifulSoup

# %%
html_string = """
<html lang="en">
    <head>
        <title>Jindal Home</title>
        <meta charset="utf-8">
        <script	src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>
        <script src="https://code.jquery.com/jquery-3.1.1.min.js"></script>
        <link rel="stylesheet" href="style.css" type="text/css"/>
       
    </head>
    <body >
            <div class="start"></div>
             <div class="divimage" > <img id="logo" src="jindallogo.jpg" /></div>
    <br>
    <div class="enclosecenter">
        <div class="center">


            <div class="divselect"> 
                <form id="defaultform">
                    <select id="select" name="select-profession" onchange="showTableData()">
                        <option value="NaN" selected disabled> select an option</option>
                        <option value="HR"> HR</option>
                        <option value="Finance"> Finance</option>
                        <option value="Legal"> Legal</option>
                    </select> 

                    <input type="button" value=" Add " id="0"  class="mainbutton"/>
                    <input type="button" value=" Delete " id="1"  class="mainbutton" /> 
                    <input type="button" value=" Update " id="2" class="mainbutton"/> 
                </form>
            </div>	

            <div id="addModal" class="modal">
                <div class="modal-content">
                    <span class="close">&times;</span>
                    <div class="formclass" id="divadd">
                        <p class="text"> Enter Details :  </p>
                        <input type="text" id="addfname" class="inputText"	placeholder="First Name" /> 
                        <input type="text" id="addlname" class="inputText" placeholder="Last Name" />
                        <button type="submit" id="submit" onclick="addRequest()" class="button">Submit</button>
                    </div>
                </div>
            </div>

            <div id="deleteModal" class="modal">
                <div class="modal-content">
                    <span class="close">&times;</span>

                    <!-- ## Div for deletion of an element ## -->
                    <div class="formclass" id="divdelete">
                        <p class="text"> Enter the Id to be deleted </p>
                        <input type="text" id="getid" placeholder="Id" class="inputText">
                        <button id="deleteid" onclick="deleteId()" class="button">Delete</button>
                    </div>
                </div>
            </div>

            <div id="updateModal" class="modal">
                <!-- Modal content -->
                <div class="modal-content">
                    <span class="close">&times;</span>

                    <!-- ## Div for addition of an element ## -->
                    <div class="formclass" id="divupdate">
                        <!--<form id="addform" role="form" method=post action="">-->
                        <p class="text"> Enter Details :  </p>
                        <input type="text" id="addfname" class="inputText"	placeholder="First Name" /> 
                        <input type="text" id="addlname" class="inputText" placeholder="Last Name" />
                        <button type="submit" id="submit" onclick="addRequest()" class="button">Submit</button>
                    </div>
                </div>
            </div>
            <b id="tableName"></b>
            <div>
                <table id="DataTable" border="1"></table>
            </div>
                    </div>

    </div>

    <script type="text/javascript">
        var myList;
        function insertData() {
	var fname=document.getElementById("fname").value;
	var lname=document.getElementById("lname").value;
	var email=document.getElementById("email").value;
	var pnumber=document.getElementById("pnumber").value;
	var hiredate=document.getElementById("hiredate").value;
	var jobid=document.getElementById("jobid").value;
	var salary=document.getElementById("salary").value;
	var managerid=document.getElementById("managerid").value;
	var departmentid=document.getElementById("departmentid").value;
	
	var d={"first_name":fname,"last_name":lname,"email":email,"phone_number":pnumber,"hire_date":hiredate,"job_id":jobid,"salary":salary,"manager_id":managerid,"department_id":departmentid };
	d=JSON.stringify(d);
	alert(d);
	$.ajax(
			{
			url: "http://10.22.42.18:8085/AddEmp",
			type: "POST",
			data: d,
			success : function (maindta){
				alert("User Added");
			},
			error: function (maindta){
				alert("Couldn't add user");
			}
			});
}
        function showTableData(){
            //document.getElementById("DataTable").style.visibility="visible";
            document.getElementById("tableName").innerHTML = "Table : "+document.getElementById("select").value;
            document.getElementById("DataTable").innerHTML = "";
            var country=[{"code":"ABW","continent":"North America","governmentForm":"Nonmetropolitan Territory of The Netherlands","name":"Aruba","region":"Caribbean"},{"code":"AFG","continent":"Asia","governmentForm":"Islamic Emirate","name":"Afghanistan","region":"Southern and Central Asia"},{"code":"AGO","continent":"Africa","governmentForm":"Republic","name":"Angola","region":"Central Africa"},{"code":"AIA","continent":"North America","governmentForm":"Dependent Territory of the UK","name":"Anguilla","region":"Caribbean"}];
            myList=JSON.stringify(country);
            myList=JSON.parse(myList);
                buildHtmlTable("#DataTable");

	/* $.ajax(
			{
			url: "http://localhost:8085/TestPortal/webapi/myresource/country",
			type: "POST",
			success:function(maindta)
			{
				myList=JSON.stringify(maindta);
				myList=JSON.parse(myList);
				buildHtmlTable("#DataTable");
			}
			});*/
        }

                        
        function buildHtmlTable(selector) {

            var columns = addAllColumnHeaders(myList, selector);
            for (var i = 0; i < myList.length; i++) {
                 var row$ = $('<tr/>');
                 for (var colIndex = 0; colIndex < columns.length; colIndex++) {
                     var cellValue = myList[i][columns[colIndex]];
                        if (cellValue == null) cellValue = "";
                            row$.append($('<td/>').html(cellValue));
                 }
                $(selector).append(row$);
            }
        }

        function addAllColumnHeaders(myList, selector) {
            var columnSet = [];
            var headerTr$ = $('<tr/>');
            for (var i = 0; i < myList.length; i++) {
                var rowHash = myList[i];
                for (var key in rowHash) {
                    if ($.inArray(key, columnSet) == -1) {
                        columnSet.push(key);
                        headerTr$.append($('<th/>').html(key));
                    }
                }
            }
            $(selector).append(headerTr$);
            return columnSet;
        }

        $(document).ready(function() {
            $(".mainbutton").click(function(){
                if(($('#select').find(":selected").attr('value'))=="NaN")
                    alert("Please Select Department");
                else
                    $('.modal')[this.id].style.display = "block";
            }); 
        });
        
        $(document).on('click','.close',function(){
            $('.modal')[0].style.display = "none";
            $('.modal')[1].style.display = "none";
            $('.modal')[2].style.display = "none";
            });
        
        $(window).click(function(e) {
            if(e.target.className == "modal"){
            $('.modal')[0].style.display = "none";
            $('.modal')[1].style.display = "none";
            $('.modal')[2].style.display = "none";
            } 
        });
        
    </script>

    </body>
</html>"""

# %%
from IPython.core.display import display,HTML
display(HTML(html_string))
# Out:
# <html lang="en">
#     <head>
#         <title>Jindal Home</title>
#         <meta charset="utf-8">
#         <script	src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>
#         <script src="https://code.jquery.com/jquery-3.1.1.min.js"></script>
#         <link rel="stylesheet" href="style.css" type="text/css"/>
#
#     </head>
#     <body >
#             <div class="start"></div>
#              <div class="divimage" > <img id="logo" src="jindallogo.jpg" /></div>
#     <br>
#     <div class="enclosecenter">
#         <div class="center">
#
#
#             <div class="divselect">
#                 <form id="defaultform">
#                     <select id="select" name="select-profession" onchange="showTableData()">
#                         <option value="NaN" selected disabled> select an option</option>
#                         <option value="HR"> HR</option>
#                         <option value="Finance"> Finance</option>
# ...

# %%
ps = BeautifulSoup(html_string)
# Out:
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print(ps)
# Out:
# <html lang="en">
# <head>
# <title>Jindal Home</title>
# <meta charset="utf-8"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>
# <script src="https://code.jquery.com/jquery-3.1.1.min.js"></script>
# <link href="style.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div class="start"></div>
# <div class="divimage"> <img id="logo" src="jindallogo.jpg"/></div>
# <br/>
# <div class="enclosecenter">
# <div class="center">
# <div class="divselect">
# <form id="defaultform">
# <select id="select" name="select-profession" onchange="showTableData()">
# <option disabled="" selected="" value="NaN"> select an option</option>
# <option value="HR"> HR</option>
# <option value="Finance"> Finance</option>
# <option value="Legal"> Legal</option>
# </select>
# <input class="mainbutton" id="0" type="button" value=" Add "/>
# <input class="mainbutton" id="1" type="button" value=" Delete "/>
# ...

# %%
body = ps.find(name="body")
print(body)
# Out:
# <body>
# <div class="start"></div>
# <div class="divimage"> <img id="logo" src="jindallogo.jpg"/></div>
# <br/>
# <div class="enclosecenter">
# <div class="center">
# <div class="divselect">
# <form id="defaultform">
# <select id="select" name="select-profession" onchange="showTableData()">
# <option disabled="" selected="" value="NaN"> select an option</option>
# <option value="HR"> HR</option>
# <option value="Finance"> Finance</option>
# <option value="Legal"> Legal</option>
# </select>
# <input class="mainbutton" id="0" type="button" value=" Add "/>
# <input class="mainbutton" id="1" type="button" value=" Delete "/>
# <input class="mainbutton" id="2" type="button" value=" Update "/>
# </form>
# </div>
# <div class="modal" id="addModal">
# <div class="modal-content">
# <span class="close">×</span>
# <div class="formclass" id="divadd">
# <p class="text"> Enter Details :  </p>
# <input class="inputText" id="addfname" placeholder="First Name" type="text"/>
# ...

# %%
print(body.find_all(name="option"))
# Out:
# [<option disabled="" selected="" value="NaN"> select an option</option>, <option value="HR"> HR</option>, <option value="Finance"> Finance</option>, <option value="Legal"> Legal</option>]

# %%
for p in body.find_all(name='option'):
    print(p.text)
# Out:
#  select an option
#  HR
#  Finance
#  Legal

# %%
print(body.find(name="button",attrs={"id":"submit"}))
# Out:
# <button class="button" id="submit" onclick="addRequest()" type="submit">Submit</button>

# %%
for i in range(1,10)[1:]:
    print(i)
    
a = [1,2,3,3,4,2]
for i,j in enumerate(a):
    print(i,j)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0 1
# 1 2
# 2 3
# 3 3
# 4 4
# 5 2

# %% [markdown]
# ## Titanic data scraping
# We will store the username and password in the .env file
# as KAGGLE_USERNAME and KAGGLE_PASSWORD
# - open .gitignore and .env is there ie. it wouldnt not be pushed for versioning control

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv,find_dotenv
# find the .env automatically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)
print(dotenv_path)
# Out:
# C:\Users\vivek.kumar5\Desktop\PyDataSc\project\titanic\.env

# %%
# using os library to get the environment variable values
import os
KAGGLE_USERNAME = os.environ.get("KAGGLE_USERNAME")
print(KAGGLE_USERNAME)
# Out:
# vivekhm3415@gmail.com

# %%
# imports
import requests
from requests import session
import os
from dotenv import load_dotenv, find_dotenv

# %%
# payload for post
payload = {
    'action':'login',
    'username': os.environ.get("KAGGLE_USERNAME"),
    'password': os.environ.get("KAGGLE_PASSWORD")
}

# url for the training data
url = "https://www.kaggle.com/c/3136/download/train.csv"

# setup session
with session() as c:
    # post request
    c.post('https://www.kaggle.com/account/login',data=payload)
    # get request
    response = c.get(url)
    print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Kaggle: Your Home for Data Science</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow"/>
#         <meta name="theme-color" content="#008ABC" />
#     <link rel="dns-prefetch" href="https://www.google-analytics.com" /><link rel="dns-prefetch" href="https://stats.g.doubleclick.net" /><link rel="dns-prefetch" href="https://js.intercomcdn.com" /><link rel="preload" href="https://az416426.vo.msecnd.net/scripts/a/ai.0.js" as=script /><link rel="dns-prefetch" href="https://kaggle2.blob.core.windows.net" />
#     <link href="/content/v/d420a040e581/kaggle/favicon.ico" rel="shortcut icon" type="image/x-icon" />
#     <link rel="manifest" href="/static/json/manifest.json">
#     <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel='stylesheet' type='text/css'>
# ...

# %%
from requests import session
payload = {
    'action':'login',
    'username': os.environ.get("KAGGLE_USERNAME"),
    'password': os.environ.get("KAGGLE_PASSWORD")
}

def extract_data(url, file_path):
    with session() as c:
        c.post('https://www.kaggle.com/account/login',data=payload)
        # open file to write
        with open(file_path, 'w') as handle:
        # using a with statement we get, better syntax and it will 
        # automatically close the resources like file
            response = c.get(url,stream=True)
            # stream is True so that we get response as a stream
            for block in response.iter_content(1024):
                handle.write(str(block))

# %%
# now we will get both the train and the test data
train_url = "https://www.kaggle.com/c/3136/download/train.csv"
test_url = "https://www.kaggle.com/c/3136/download/test.csv"

# file paths
raw_data_path = os.path.join(os.path.pardir,"data","raw")
train_data_path = os.path.join(raw_data_path,'train.csv')
test_data_path = os.path.join(raw_data_path,'test.csv')

# extract data
extract_data(train_url,train_data_path)
extract_data(test_url,test_data_path)

# %%
# checking the raw folder
# !dir ..\data\raw
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 42C8-AF38
#
#  Directory of C:\Users\vivek.kumar5\Desktop\PyDataSc\project\titanic\data\raw
#
# 26-Apr-18  05:38 PM    <DIR>          .
# 26-Apr-18  05:38 PM    <DIR>          ..
# 20-Mar-18  03:23 PM                 0 .gitkeep
# 26-Apr-18  05:41 PM             8,723 test.csv
# 26-Apr-18  05:41 PM             8,723 train.csv
#                3 File(s)         17,446 bytes
#                2 Dir(s)  88,824,147,968 bytes free

# %% [markdown]
# ## Building the file Script

# %%
import os
get_raw_data_script_file = os.path.join(os.path.pardir,'src','data','get_raw_data.py')
print(get_raw_data_script_file)
# Out:
# ..\src\data\get_raw_data.py

# %%
# %%writefile $get_raw_data_script_file
# import os
# from dotenv import find_dotenv, load_dotenv
# from requests import session
# import logging
#
# # payload for login to kaggle
# payload = {
#     'action':'login',
#     'username': os.environ.get("KAGGLE_USERNAME"),
#     'password': os.environ.get("KAGGLE_PASSWORD")
# }
#
# def extract_data(url, file_path):
#     with session() as c:
#         c.post('https://www.kaggle.com/account/login',data=payload)
#         # open file to write
#         with open(file_path, 'w') as handle:
#         # using a with statement we get, better syntax and it will
#         # automatically close the resources like file
#             response = c.get(url,stream=True)
#             # stream is True so that we get response as a stream
#             for block in response.iter_content(1024):
#                 handle.write(str(block))
#
# def main(project_dir):
#
#     # get logger
#     logger = logging.getLogger(__name__)
#     logger.info('getting raw data')
#
#     # urls
#     train_url = "https://www.kaggle.com/c/3136/download/train.csv"
#     test_url = "https://www.kaggle.com/c/3136/download/test.csv"
#
#     # file paths
#     raw_data_path = os.path.join(os.path.pardir,"data","raw")
#     train_data_path = os.path.join(raw_data_path,'train.csv')
#     test_data_path = os.path.join(raw_data_path,'test.csv')
#
#     # extract data
#     extract_data(train_url,train_data_path)
#     extract_data(test_url,test_data_path)
#     logger.info('downloaded raw training and test data')
#
# if __name__ == '__main__':
#     # getting the root directory
#     project_dir = os.path.join(os.path.dirname(__file__),os.pardir,os.pardir)
#     print("project directory is:",project_dir)
#
#     # setup logger and log format
#     log_fmt = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
#     logging.basicConfig(level=logging.INFO, format=log_fmt)
#
#     # find .env
#     dotenv_path = find_dotenv()
#     # load up entries as environmental variables
#     load_dotenv(dotenv_path)
#
#     # call the main
#     main(project_dir)
# Out:
# Writing ..\src\data\get_raw_data.py

# %%
# !python $get_raw_data_script_file
# Out:
# project directory is: ..\src\data\..\..
# 2018-04-26 17:43:00,998 - __main__ - INFO - getting raw data
# 2018-04-26 17:43:04,319 - __main__ - INFO - downloaded raw training and test data

# %% [markdown]
# ## Public datasets
# 1. Data.gov
# 2. AWS public datasets
# 3. UCI machine learning repository
# 4. github repository : caesar0301 / awesome-public-datasets
